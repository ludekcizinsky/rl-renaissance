# %%
import pandas as pd

# %%
df = pd.read_csv('../models/varma_ecoli_shikki/steady_state_samples/samples_fdp1.csv').drop(columns=['Unnamed: 0'])
df.head()
# Out:
#    DM_4CRSOL  DM_4CRSOL_reverse_50477  DM_5DRIB  DM_5DRIB_reverse_0b428  \
# 0   0.000070                      0.0  0.000351                     0.0
# 1   0.000069                      0.0  0.000349                     0.0
# 2   0.000070                      0.0  0.000352                     0.0
# 3   0.000069                      0.0  0.000350                     0.0
# 4   0.000069                      0.0  0.000350                     0.0
#
#         DM_AMOB  DM_AMOB_reverse_9e172  DM_MTHTHF  DM_MTHTHF_reverse_78338  \
# 0  6.245378e-07                    0.0   0.000418                      0.0
# 1  6.210615e-07                    0.0   0.000416                      0.0
# 2  6.276285e-07                    0.0   0.000421                      0.0
# 3  6.227640e-07                    0.0   0.000417                      0.0
# 4  6.225069e-07                    0.0   0.000417                      0.0
#
#    DM_5mtr_e  DM_5mtr_e_reverse_5ec79  ...  LC_zn2_e  LC_zn2_p  \
# ...

# %%
df.iloc[1711]
# Out:
# DM_4CRSOL                       6.920025e-05
# DM_4CRSOL_reverse_50477         0.000000e+00
# DM_5DRIB                        3.484838e-04
# DM_5DRIB_reverse_0b428          0.000000e+00
# DM_AMOB                         6.206301e-07
#                                     ...
# LC_anth_e                      -1.145992e+01
# LnGamma_ANTHtex                -1.000000e-03
# DG_LMPD_biomass_c_1_420        -5.920894e-04
# DGo_LMPD_biomass_c_1_420        1.161610e+08
# LnGamma_LMPD_biomass_c_1_420   -1.000000e-03
# Name: 1711, Length: 1126, dtype: float64
