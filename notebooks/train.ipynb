# %%
from functools import partial
import numpy as np
from matplotlib import pyplot as plt
import torch

import hydra
from omegaconf import DictConfig, OmegaConf

from renaissance.kinetics.jacobian_solver import check_jacobian

from helpers.ppo_agent import PPOAgent
from helpers.env import KineticEnv, KineticEnvStateless
from helpers.utils import reward_func, load_pkl

import logging
from hydra import initialize, compose
initialize(config_path="configs", version_base="1.1")
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-ici528wo because the default path (/home/renaissance/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# hydra.initialize()

# %%
cfg = compose(config_name="train.yaml")

# %%
print("-" * 50)
print(OmegaConf.to_yaml(cfg))  # print config to verify
print("-" * 50)

# Call solvers from SKimPy
chk_jcbn = check_jacobian()
logging.disable(logging.CRITICAL)

# Integrate data
print("FYI: Loading kinetic and thermodynamic data.")
chk_jcbn._load_ktmodels(cfg.paths.met_model_name, 'fdp1') # Load kinetic and thermodynamic data
chk_jcbn._load_ssprofile(cfg.paths.met_model_name, 'fdp1', cfg.constraints.ss_idx) # Integrate steady state information

# Logger setup, todo: for now disabled, else we would get w&b run object
logger = None # get_logger(cfg)
# Out:
# --------------------------------------------------
# method:
#   parameter_dim: 384
#   latent_dim: 99
#   name: ppo_refinement
#   actor_lr: 0.0003
#   critic_lr: 0.001
#   discount_factor: 0.99
#   gae_lambda: 0.98
#   clip_eps: 0.2
#   value_loss_weight: 0.5
#   entropy_loss_weight: 0.0
# seed: 42
# device: cpu
# logger:
#   project: rl-renaissance
#   entity: ludekcizinsky
#   tags:
#   - dev
# paths:
#   names_km: data/varma_ecoli_shikki/parameter_names_km_fdp1.pkl
#   output_dir: /home/renaissance/work/output
#   met_model_name: varma_ecoli_shikki
# constraints:
#   min_km: -25
#   max_km: 3
#   ss_idx: 1712
# reward:
#   eig_partition: -2.5
#   intermediate_steps_weight: 1.0
# env:
#   p0_init_mean: 0
#   p0_init_std: 1
#   p_size: 384
#   action_scale: 1.0
# training:
#   num_episodes: 100
#   max_steps_per_episode: 50
#   batch_size: 25
#   num_epochs: 10
#   max_grad_norm: 0.5
#   n_dist_samples: 1
#
# --------------------------------------------------
# FYI: Loading kinetic and thermodynamic data.

# %%
# Initialize environment
names_km = load_pkl(cfg.paths.names_km)
reward_fn = partial(reward_func, chk_jcbn, names_km, cfg.reward.eig_partition)
env = KineticEnv(cfg, reward_fn)
env.seed(cfg.seed)

# %%
import os
run_id = 0
# go through cfg.paths.output_dir and count the number of runs
for i in range(1000):
    if os.path.exists(os.path.join(cfg.paths.output_dir, f"run_{i}")):
        run_id += 1
    else:
        break

# %%
import time
# Initialize PPO agent (actor and critic)
ppo_agent = PPOAgent(cfg, logger)

# %%
collect_rewards = []
collect_policy_loss = []
collect_value_loss = []
best_reward = float("-inf")
save_dir = os.path.join(cfg.paths.output_dir, f"run_{run_id}")
os.makedirs(save_dir, exist_ok=True)
# Training loop
episode_start_time = time.time()  # Track time for first episode

for episode in range(cfg.training.num_episodes):
    trajectory = ppo_agent.collect_trajectory(env)
    rewards = trajectory["rewards"]
    collect_rewards.append(rewards.numpy())
    min_rew, max_rew, mean_rew = rewards.min(), rewards.max(), rewards.mean()
    print(f"Episode {episode+1}/{cfg.training.num_episodes} - Min reward: {min_rew:.4f}, Max reward: {max_rew:.4f}, Mean reward: {mean_rew:.4f}, Last reward: {rewards[-1]:.4f}")

    policy_loss, value_loss, entropy = ppo_agent.update(trajectory)
    print(f"Episode {episode+1}/{cfg.training.num_episodes} - Policy loss: {policy_loss:.4f}, Value loss: {value_loss:.4f}, Entropy: {entropy:.4f}")

    episode_end_time = time.time()
    elapsed = episode_end_time - episode_start_time
    print(f"Time elapsed for episode {episode+1}: {elapsed:.2f} seconds")
    episode_start_time = episode_end_time
    
    collect_policy_loss.append(policy_loss)
    collect_value_loss.append(value_loss)

    # Save the best model based on the mean reward
    if rewards[-1] > best_reward:
        best_reward = rewards[-1]
        actor = ppo_agent.policy_net
        critic = ppo_agent.value_net
        torch.save(ppo_agent.policy_net.state_dict(), os.path.join(save_dir, f"actor_best.pth"))
        torch.save(ppo_agent.value_net.state_dict(), os.path.join(save_dir, f"critic_best.pth"))
        # Save the training data
        np.save(os.path.join(save_dir, "rewards.npy"), np.array(collect_rewards))
        np.save(os.path.join(save_dir, "policy_loss.npy"), np.array(collect_policy_loss))
        np.save(os.path.join(save_dir, "value_loss.npy"), np.array(collect_value_loss))
        # save the config file
        with open(os.path.join(save_dir, "config.yaml"), "w") as f:
            f.write(OmegaConf.to_yaml(cfg))

        print(f"Model saved at episode {episode + 1} with reward {rewards[-1]:.4f}")

# Save the training data
np.save(os.path.join(save_dir, "rewards.npy"), np.array(collect_rewards))
np.save(os.path.join(save_dir, "policy_loss.npy"), np.array(collect_policy_loss))
np.save(os.path.join(save_dir, "value_loss.npy"), np.array(collect_value_loss))
# save the config file
with open(os.path.join(save_dir, "config.yaml"), "w") as f:
    f.write(OmegaConf.to_yaml(cfg))
# Out:
# Episode 1/100 - Min reward: 0.0010, Max reward: 0.0985, Mean reward: 0.0533, Last reward: 0.0791
# Episode 1/100 - Policy loss: 0.4318, Value loss: 5.3430, Entropy: 544.9367
# Time elapsed for episode 1: 10.69 seconds
# Model saved at episode 1 with reward 0.0791
# Episode 2/100 - Min reward: 0.0010, Max reward: 0.1229, Mean reward: 0.0607, Last reward: 0.0261
# Episode 2/100 - Policy loss: 0.3647, Value loss: 1.9564, Entropy: 544.8965
# Time elapsed for episode 2: 10.81 seconds
# Episode 3/100 - Min reward: 0.0010, Max reward: 0.0778, Mean reward: 0.0726, Last reward: 0.0770
# Episode 3/100 - Policy loss: 0.2774, Value loss: 1.1280, Entropy: 544.7775
# Time elapsed for episode 3: 10.74 seconds
# Episode 4/100 - Min reward: 0.0010, Max reward: 0.1104, Mean reward: 0.0446, Last reward: 0.0010
# Episode 4/100 - Policy loss: 0.3291, Value loss: 5.3262, Entropy: 544.7476
# Time elapsed for episode 4: 10.67 seconds
# Episode 5/100 - Min reward: 0.0053, Max reward: 0.0908, Mean reward: 0.0556, Last reward: 0.0777
# Episode 5/100 - Policy loss: 0.5209, Value loss: 23.0776, Entropy: 544.6843
# Time elapsed for episode 5: 10.70 seconds
# Episode 6/100 - Min reward: 0.0010, Max reward: 0.0813, Mean reward: 0.0456, Last reward: 0.0796
# Episode 6/100 - Policy loss: 0.3232, Value loss: 12.3624, Entropy: 544.7470
# Time elapsed for episode 6: 10.73 seconds
# Model saved at episode 6 with reward 0.0796
# Episode 7/100 - Min reward: 0.0010, Max reward: 0.0774, Mean reward: 0.0725, Last reward: 0.0771
# Episode 7/100 - Policy loss: 0.4025, Value loss: 2.9388, Entropy: 544.7939
# Time elapsed for episode 7: 10.77 seconds
# Episode 8/100 - Min reward: 0.0202, Max reward: 0.4331, Mean reward: 0.2047, Last reward: 0.1116
# Episode 8/100 - Policy loss: 0.0895, Value loss: 1.9611, Entropy: 544.4589
# Time elapsed for episode 8: 10.74 seconds
# Model saved at episode 8 with reward 0.1116
# Episode 9/100 - Min reward: 0.0010, Max reward: 0.0795, Mean reward: 0.0420, Last reward: 0.0772
# Episode 9/100 - Policy loss: 0.1313, Value loss: 14.4247, Entropy: 544.2692
# Time elapsed for episode 9: 10.78 seconds
# Episode 10/100 - Min reward: 0.0010, Max reward: 0.0914, Mean reward: 0.0594, Last reward: 0.0634
# Episode 10/100 - Policy loss: 0.2235, Value loss: 11.0150, Entropy: 544.0695
# Time elapsed for episode 10: 10.78 seconds
# Episode 11/100 - Min reward: 0.0258, Max reward: 0.2079, Mean reward: 0.0854, Last reward: 0.0806
# Episode 11/100 - Policy loss: 0.2785, Value loss: 3.4141, Entropy: 544.0500
# Time elapsed for episode 11: 10.79 seconds
# Episode 12/100 - Min reward: 0.0024, Max reward: 0.4843, Mean reward: 0.0767, Last reward: 0.0772
# Episode 12/100 - Policy loss: 0.0312, Value loss: 11.8412, Entropy: 544.0079
# Time elapsed for episode 12: 10.72 seconds
# Episode 13/100 - Min reward: 0.0011, Max reward: 0.1130, Mean reward: 0.0640, Last reward: 0.0772
# Episode 13/100 - Policy loss: 0.3059, Value loss: 21.2794, Entropy: 543.9630
# Time elapsed for episode 13: 10.77 seconds
# Episode 14/100 - Min reward: 0.0010, Max reward: 0.1504, Mean reward: 0.0494, Last reward: 0.0010
# Episode 14/100 - Policy loss: -0.0147, Value loss: 24.8382, Entropy: 543.9632
# Time elapsed for episode 14: 10.71 seconds
# Episode 15/100 - Min reward: 0.0013, Max reward: 0.3896, Mean reward: 0.1171, Last reward: 0.0602
# Episode 15/100 - Policy loss: 0.1255, Value loss: 8.8305, Entropy: 543.9520
# Time elapsed for episode 15: 10.67 seconds
# Episode 16/100 - Min reward: 0.0010, Max reward: 0.1274, Mean reward: 0.0654, Last reward: 0.0010
# Episode 16/100 - Policy loss: 0.0366, Value loss: 13.1869, Entropy: 543.9510
# Time elapsed for episode 16: 10.73 seconds
# Episode 17/100 - Min reward: 0.0038, Max reward: 0.1143, Mean reward: 0.0720, Last reward: 0.0768
# Episode 17/100 - Policy loss: -0.0428, Value loss: 21.6537, Entropy: 543.8778
# Time elapsed for episode 17: 10.82 seconds
# Episode 18/100 - Min reward: 0.0010, Max reward: 0.1946, Mean reward: 0.0249, Last reward: 0.0010
# Episode 18/100 - Policy loss: -0.0391, Value loss: 11.8508, Entropy: 543.7972
# Time elapsed for episode 18: 10.73 seconds
# Episode 19/100 - Min reward: 0.0772, Max reward: 0.1875, Mean reward: 0.0942, Last reward: 0.0772
# Episode 19/100 - Policy loss: -0.0219, Value loss: 2.9694, Entropy: 543.7648
# Time elapsed for episode 19: 10.76 seconds
# Episode 20/100 - Min reward: 0.0314, Max reward: 0.1194, Mean reward: 0.0817, Last reward: 0.0772
# Episode 20/100 - Policy loss: -0.2269, Value loss: 3.2102, Entropy: 543.8999
# Time elapsed for episode 20: 10.80 seconds
# Episode 21/100 - Min reward: 0.0010, Max reward: 0.0786, Mean reward: 0.0363, Last reward: 0.0010
# Episode 21/100 - Policy loss: -0.0718, Value loss: 9.2149, Entropy: 543.8862
# Time elapsed for episode 21: 10.83 seconds
# Episode 22/100 - Min reward: 0.0010, Max reward: 0.0772, Mean reward: 0.0681, Last reward: 0.0772
# Episode 22/100 - Policy loss: 0.0305, Value loss: 4.2860, Entropy: 543.8473
# Time elapsed for episode 22: 10.84 seconds
# Episode 23/100 - Min reward: 0.0010, Max reward: 0.0996, Mean reward: 0.0725, Last reward: 0.0772
# Episode 23/100 - Policy loss: -0.0280, Value loss: 1.9518, Entropy: 543.8083
# Time elapsed for episode 23: 10.84 seconds
# Episode 24/100 - Min reward: 0.0010, Max reward: 0.0875, Mean reward: 0.0351, Last reward: 0.0863
# Episode 24/100 - Policy loss: -0.0552, Value loss: 7.8292, Entropy: 543.6729
# Time elapsed for episode 24: 10.88 seconds
# Episode 25/100 - Min reward: 0.0010, Max reward: 0.2542, Mean reward: 0.0351, Last reward: 0.0772
# Episode 25/100 - Policy loss: 0.0533, Value loss: 0.7155, Entropy: 543.6421
# Time elapsed for episode 25: 10.81 seconds
# Episode 26/100 - Min reward: 0.0010, Max reward: 0.1661, Mean reward: 0.0599, Last reward: 0.0773
# Episode 26/100 - Policy loss: -0.0229, Value loss: 7.5739, Entropy: 543.7146
# Time elapsed for episode 26: 10.78 seconds
# Episode 27/100 - Min reward: 0.0010, Max reward: 0.1105, Mean reward: 0.0599, Last reward: 0.1103
# Episode 27/100 - Policy loss: -0.1366, Value loss: 6.8686, Entropy: 543.7178
# Time elapsed for episode 27: 10.83 seconds
# Episode 28/100 - Min reward: 0.0010, Max reward: 0.0772, Mean reward: 0.0056, Last reward: 0.0772
# Episode 28/100 - Policy loss: -0.2293, Value loss: 1.0791, Entropy: 543.6915
# Time elapsed for episode 28: 10.83 seconds
# Episode 29/100 - Min reward: 0.0010, Max reward: 0.0811, Mean reward: 0.0670, Last reward: 0.0772
# Episode 29/100 - Policy loss: -0.2907, Value loss: 11.9890, Entropy: 543.5861
# Time elapsed for episode 29: 10.74 seconds
# Episode 30/100 - Min reward: 0.0010, Max reward: 0.1952, Mean reward: 0.0738, Last reward: 0.0772
# Episode 30/100 - Policy loss: -0.1866, Value loss: 2.3008, Entropy: 543.5650
# Time elapsed for episode 30: 10.76 seconds
# Episode 31/100 - Min reward: 0.0784, Max reward: 0.3314, Mean reward: 0.0925, Last reward: 0.0785
# Episode 31/100 - Policy loss: 0.1435, Value loss: 3.3027, Entropy: 543.6251
# Time elapsed for episode 31: 10.77 seconds
# Episode 32/100 - Min reward: 0.0010, Max reward: 0.1076, Mean reward: 0.0441, Last reward: 0.0010
# Episode 32/100 - Policy loss: -0.0073, Value loss: 6.6205, Entropy: 543.6300
# Time elapsed for episode 32: 10.82 seconds
# Episode 33/100 - Min reward: 0.0010, Max reward: 0.1810, Mean reward: 0.0826, Last reward: 0.0921
# Episode 33/100 - Policy loss: 0.0679, Value loss: 9.3413, Entropy: 543.5699
# Time elapsed for episode 33: 10.82 seconds
# Episode 34/100 - Min reward: 0.0010, Max reward: 0.0890, Mean reward: 0.0649, Last reward: 0.0880
# Episode 34/100 - Policy loss: -0.1058, Value loss: 13.5915, Entropy: 543.5129
# Time elapsed for episode 34: 10.79 seconds
# Episode 35/100 - Min reward: 0.0010, Max reward: 0.1382, Mean reward: 0.0749, Last reward: 0.0010
# Episode 35/100 - Policy loss: -0.4404, Value loss: 29.0104, Entropy: 543.3236
# Time elapsed for episode 35: 10.73 seconds
# Episode 36/100 - Min reward: 0.0010, Max reward: 0.1192, Mean reward: 0.0526, Last reward: 0.0010
# Episode 36/100 - Policy loss: -0.0864, Value loss: 7.1605, Entropy: 543.3088
# Time elapsed for episode 36: 10.79 seconds
# Episode 37/100 - Min reward: 0.0769, Max reward: 0.0871, Mean reward: 0.0791, Last reward: 0.0795
# Episode 37/100 - Policy loss: -0.3021, Value loss: 16.0440, Entropy: 543.3633
# Time elapsed for episode 37: 10.76 seconds
# Episode 38/100 - Min reward: 0.0432, Max reward: 0.2255, Mean reward: 0.0907, Last reward: 0.0865
# Episode 38/100 - Policy loss: -0.2394, Value loss: 5.9476, Entropy: 543.4002
# Time elapsed for episode 38: 10.78 seconds
# Episode 39/100 - Min reward: 0.0010, Max reward: 0.4840, Mean reward: 0.1462, Last reward: 0.0867
# Episode 39/100 - Policy loss: 0.2632, Value loss: 10.1194, Entropy: 543.4144
# Time elapsed for episode 39: 10.83 seconds
# Episode 40/100 - Min reward: 0.0010, Max reward: 0.0815, Mean reward: 0.0689, Last reward: 0.0813
# Episode 40/100 - Policy loss: -0.1722, Value loss: 6.9600, Entropy: 543.4636
# Time elapsed for episode 40: 10.84 seconds
# Episode 41/100 - Min reward: 0.0010, Max reward: 0.0857, Mean reward: 0.0594, Last reward: 0.0772
# Episode 41/100 - Policy loss: -0.1673, Value loss: 37.9408, Entropy: 543.5230
# Time elapsed for episode 41: 10.77 seconds
# Episode 42/100 - Min reward: 0.0010, Max reward: 0.0790, Mean reward: 0.0145, Last reward: 0.0013
# Episode 42/100 - Policy loss: -0.1763, Value loss: 22.8370, Entropy: 543.4786
# Time elapsed for episode 42: 10.77 seconds
# Episode 43/100 - Min reward: 0.0010, Max reward: 0.0976, Mean reward: 0.0679, Last reward: 0.0772
# Episode 43/100 - Policy loss: -0.0683, Value loss: 10.8884, Entropy: 543.3317
# Time elapsed for episode 43: 10.75 seconds
# Episode 44/100 - Min reward: 0.0010, Max reward: 0.0772, Mean reward: 0.0557, Last reward: 0.0772
# Episode 44/100 - Policy loss: -0.1044, Value loss: 5.8232, Entropy: 543.4091
# Time elapsed for episode 44: 10.82 seconds
# Episode 45/100 - Min reward: 0.0011, Max reward: 0.4323, Mean reward: 0.0923, Last reward: 0.0794
# Episode 45/100 - Policy loss: -0.1882, Value loss: 2.8197, Entropy: 543.4417
# Time elapsed for episode 45: 10.84 seconds
# Episode 46/100 - Min reward: 0.0770, Max reward: 0.1123, Mean reward: 0.0842, Last reward: 0.0773
# Episode 46/100 - Policy loss: -0.1423, Value loss: 3.9270, Entropy: 543.4254
# Time elapsed for episode 46: 10.78 seconds
# Episode 47/100 - Min reward: 0.0770, Max reward: 0.4175, Mean reward: 0.1206, Last reward: 0.0796
# Episode 47/100 - Policy loss: -0.0559, Value loss: 8.5336, Entropy: 543.3917
# Time elapsed for episode 47: 10.77 seconds
# Episode 48/100 - Min reward: 0.0010, Max reward: 0.1342, Mean reward: 0.0638, Last reward: 0.0797
# Episode 48/100 - Policy loss: -0.0290, Value loss: 38.2881, Entropy: 543.3906
# Time elapsed for episode 48: 10.75 seconds
# Episode 49/100 - Min reward: 0.0010, Max reward: 0.2316, Mean reward: 0.1151, Last reward: 0.1099
# Episode 49/100 - Policy loss: -0.1188, Value loss: 14.0525, Entropy: 543.3934
# Time elapsed for episode 49: 10.78 seconds
# Episode 50/100 - Min reward: 0.0433, Max reward: 0.2144, Mean reward: 0.0925, Last reward: 0.1720
# Episode 50/100 - Policy loss: -0.3320, Value loss: 3.6671, Entropy: 543.3621
# Time elapsed for episode 50: 10.78 seconds
# Model saved at episode 50 with reward 0.1720
# Episode 51/100 - Min reward: 0.0010, Max reward: 0.0797, Mean reward: 0.0758, Last reward: 0.0772
# Episode 51/100 - Policy loss: -0.1870, Value loss: 4.3904, Entropy: 543.3962
# Time elapsed for episode 51: 10.76 seconds
# Episode 52/100 - Min reward: 0.0058, Max reward: 0.0910, Mean reward: 0.0757, Last reward: 0.0770
# Episode 52/100 - Policy loss: -0.0256, Value loss: 1.4241, Entropy: 543.3152
# Time elapsed for episode 52: 10.75 seconds
# Episode 53/100 - Min reward: 0.0010, Max reward: 0.1066, Mean reward: 0.0528, Last reward: 0.0796
# Episode 53/100 - Policy loss: 0.1513, Value loss: 7.4068, Entropy: 543.3961
# Time elapsed for episode 53: 10.71 seconds
# Episode 54/100 - Min reward: 0.0010, Max reward: 0.7202, Mean reward: 0.1605, Last reward: 0.0797
# Episode 54/100 - Policy loss: -0.2266, Value loss: 5.3047, Entropy: 543.2296
# Time elapsed for episode 54: 10.78 seconds
# Episode 55/100 - Min reward: 0.0135, Max reward: 0.2421, Mean reward: 0.1135, Last reward: 0.0961
# Episode 55/100 - Policy loss: -0.1515, Value loss: 2.9967, Entropy: 543.1190
# Time elapsed for episode 55: 10.81 seconds
# Episode 56/100 - Min reward: 0.0010, Max reward: 0.0995, Mean reward: 0.0789, Last reward: 0.0992
# Episode 56/100 - Policy loss: -0.3848, Value loss: 3.6203, Entropy: 543.0573
# Time elapsed for episode 56: 10.75 seconds
# Episode 57/100 - Min reward: 0.0198, Max reward: 0.3795, Mean reward: 0.0981, Last reward: 0.0878
# Episode 57/100 - Policy loss: -0.2501, Value loss: 4.6131, Entropy: 543.0848
# Time elapsed for episode 57: 10.75 seconds
# Episode 58/100 - Min reward: 0.0010, Max reward: 0.3800, Mean reward: 0.0821, Last reward: 0.2297
# Episode 58/100 - Policy loss: -0.1653, Value loss: 1.9090, Entropy: 543.0181
# Time elapsed for episode 58: 10.70 seconds
# Model saved at episode 58 with reward 0.2297
# Episode 59/100 - Min reward: 0.0010, Max reward: 0.1817, Mean reward: 0.0851, Last reward: 0.1295
# Episode 59/100 - Policy loss: 0.0667, Value loss: 3.1850, Entropy: 543.0375
# Time elapsed for episode 59: 10.73 seconds
# Episode 60/100 - Min reward: 0.0769, Max reward: 0.1109, Mean reward: 0.0806, Last reward: 0.0772
# Episode 60/100 - Policy loss: -0.2029, Value loss: 7.6459, Entropy: 543.0112
# Time elapsed for episode 60: 10.65 seconds
# Episode 61/100 - Min reward: 0.0010, Max reward: 0.6722, Mean reward: 0.1224, Last reward: 0.0818
# Episode 61/100 - Policy loss: 0.0915, Value loss: 14.4156, Entropy: 542.9747
# Time elapsed for episode 61: 10.67 seconds
# Episode 62/100 - Min reward: 0.0770, Max reward: 0.0771, Mean reward: 0.0770, Last reward: 0.0770
# Episode 62/100 - Policy loss: -0.1333, Value loss: 7.6619, Entropy: 542.9373
# Time elapsed for episode 62: 10.74 seconds
# Episode 63/100 - Min reward: 0.0010, Max reward: 0.2044, Mean reward: 0.1019, Last reward: 0.0777
# Episode 63/100 - Policy loss: -0.0046, Value loss: 22.8195, Entropy: 543.0073
# Time elapsed for episode 63: 10.65 seconds
# Episode 64/100 - Min reward: 0.0769, Max reward: 0.1489, Mean reward: 0.0909, Last reward: 0.0815
# Episode 64/100 - Policy loss: 0.0319, Value loss: 3.5849, Entropy: 543.0929
# Time elapsed for episode 64: 10.76 seconds
# Episode 65/100 - Min reward: 0.0010, Max reward: 0.1010, Mean reward: 0.0749, Last reward: 0.0812
# Episode 65/100 - Policy loss: -0.0171, Value loss: 4.6296, Entropy: 543.1645
# Time elapsed for episode 65: 10.64 seconds
# Episode 66/100 - Min reward: 0.0010, Max reward: 0.0806, Mean reward: 0.0739, Last reward: 0.0797
# Episode 66/100 - Policy loss: -0.4384, Value loss: 5.7450, Entropy: 543.1884
# Time elapsed for episode 66: 10.69 seconds
# Episode 67/100 - Min reward: 0.0010, Max reward: 0.6142, Mean reward: 0.2602, Last reward: 0.0793
# Episode 67/100 - Policy loss: -0.1390, Value loss: 7.9236, Entropy: 543.2104
# Time elapsed for episode 67: 10.70 seconds
# Episode 68/100 - Min reward: 0.0010, Max reward: 0.3729, Mean reward: 0.0796, Last reward: 0.0797
# Episode 68/100 - Policy loss: -0.0741, Value loss: 2.6623, Entropy: 543.2123
# Time elapsed for episode 68: 10.75 seconds
# Episode 69/100 - Min reward: 0.0768, Max reward: 0.1914, Mean reward: 0.0933, Last reward: 0.0992
# Episode 69/100 - Policy loss: 0.0326, Value loss: 14.1228, Entropy: 543.1968
# Time elapsed for episode 69: 10.72 seconds
# Episode 70/100 - Min reward: 0.0770, Max reward: 0.7792, Mean reward: 0.1534, Last reward: 0.1104
# Episode 70/100 - Policy loss: -0.2574, Value loss: 6.2446, Entropy: 543.1180
# Time elapsed for episode 70: 10.70 seconds
# Episode 71/100 - Min reward: 0.0010, Max reward: 0.2063, Mean reward: 0.0781, Last reward: 0.0797
# Episode 71/100 - Policy loss: -0.0397, Value loss: 2.8200, Entropy: 543.1439
# Time elapsed for episode 71: 10.72 seconds
# Episode 72/100 - Min reward: 0.0010, Max reward: 0.7074, Mean reward: 0.1967, Last reward: 0.0814
# Episode 72/100 - Policy loss: -0.0132, Value loss: 10.6782, Entropy: 543.0859
# Time elapsed for episode 72: 10.70 seconds
# Episode 73/100 - Min reward: 0.0010, Max reward: 0.7809, Mean reward: 0.3875, Last reward: 0.7141
# Episode 73/100 - Policy loss: 0.0610, Value loss: 1.6065, Entropy: 543.2112
# Time elapsed for episode 73: 10.68 seconds
# Model saved at episode 73 with reward 0.7141
# Episode 74/100 - Min reward: 0.0010, Max reward: 0.3054, Mean reward: 0.0349, Last reward: 0.0010
# Episode 74/100 - Policy loss: -0.0921, Value loss: 8.3993, Entropy: 543.2715
# Time elapsed for episode 74: 10.71 seconds
# Episode 75/100 - Min reward: 0.0781, Max reward: 0.7166, Mean reward: 0.1431, Last reward: 0.1115
# Episode 75/100 - Policy loss: -0.3013, Value loss: 28.5659, Entropy: 543.3379
# Time elapsed for episode 75: 10.70 seconds
# Episode 76/100 - Min reward: 0.0010, Max reward: 0.7718, Mean reward: 0.2304, Last reward: 0.7426
# Episode 76/100 - Policy loss: -0.4243, Value loss: 4.3713, Entropy: 543.3583
# Time elapsed for episode 76: 10.69 seconds
# Model saved at episode 76 with reward 0.7426
# Episode 77/100 - Min reward: 0.0010, Max reward: 0.3608, Mean reward: 0.1114, Last reward: 0.3608
# Episode 77/100 - Policy loss: -0.1587, Value loss: 6.3232, Entropy: 543.2839
# Time elapsed for episode 77: 10.74 seconds
# Episode 78/100 - Min reward: 0.0010, Max reward: 0.1166, Mean reward: 0.0602, Last reward: 0.1147
# Episode 78/100 - Policy loss: 0.0740, Value loss: 8.0417, Entropy: 543.1772
# Time elapsed for episode 78: 10.70 seconds
# Episode 79/100 - Min reward: 0.0261, Max reward: 0.7793, Mean reward: 0.3418, Last reward: 0.7781
# Episode 79/100 - Policy loss: -0.3307, Value loss: 10.6188, Entropy: 543.0242
# Time elapsed for episode 79: 10.76 seconds
# Model saved at episode 79 with reward 0.7781
# Episode 80/100 - Min reward: 0.0010, Max reward: 0.2594, Mean reward: 0.1200, Last reward: 0.0010
# Episode 80/100 - Policy loss: -0.3004, Value loss: 8.1720, Entropy: 542.9017
# Time elapsed for episode 80: 10.78 seconds
# Episode 81/100 - Min reward: 0.0415, Max reward: 0.7588, Mean reward: 0.3578, Last reward: 0.6747
# Episode 81/100 - Policy loss: -0.0512, Value loss: 3.9408, Entropy: 542.9332
# Time elapsed for episode 81: 10.76 seconds
# Episode 82/100 - Min reward: 0.0798, Max reward: 0.7180, Mean reward: 0.3334, Last reward: 0.0798
# Episode 82/100 - Policy loss: -0.2157, Value loss: 1.4691, Entropy: 542.9324
# Time elapsed for episode 82: 10.74 seconds
# Episode 83/100 - Min reward: 0.0010, Max reward: 0.7212, Mean reward: 0.2284, Last reward: 0.1124
# Episode 83/100 - Policy loss: -0.4269, Value loss: 6.7675, Entropy: 542.9714
# Time elapsed for episode 83: 10.72 seconds
# Episode 84/100 - Min reward: 0.0010, Max reward: 0.7199, Mean reward: 0.1933, Last reward: 0.0998
# Episode 84/100 - Policy loss: -0.3003, Value loss: 6.5032, Entropy: 542.9490
# Time elapsed for episode 84: 10.67 seconds
# Episode 85/100 - Min reward: 0.0010, Max reward: 0.7833, Mean reward: 0.2955, Last reward: 0.1134
# Episode 85/100 - Policy loss: -0.0966, Value loss: 23.0684, Entropy: 542.8599
# Time elapsed for episode 85: 10.66 seconds
# Episode 86/100 - Min reward: 0.0769, Max reward: 0.7785, Mean reward: 0.2423, Last reward: 0.1956
# Episode 86/100 - Policy loss: -0.2626, Value loss: 10.2629, Entropy: 542.8401
# Time elapsed for episode 86: 10.66 seconds
# Episode 87/100 - Min reward: 0.0777, Max reward: 0.7706, Mean reward: 0.3520, Last reward: 0.1105
# Episode 87/100 - Policy loss: -0.3783, Value loss: 6.1020, Entropy: 542.8064
# Time elapsed for episode 87: 10.69 seconds
# Episode 88/100 - Min reward: 0.0010, Max reward: 0.7704, Mean reward: 0.2911, Last reward: 0.0771
# Episode 88/100 - Policy loss: -0.2749, Value loss: 5.5570, Entropy: 542.6808
# Time elapsed for episode 88: 10.68 seconds
# Episode 89/100 - Min reward: 0.0010, Max reward: 0.6973, Mean reward: 0.3283, Last reward: 0.1406
# Episode 89/100 - Policy loss: -0.1456, Value loss: 3.5222, Entropy: 542.5909
# Time elapsed for episode 89: 10.70 seconds
# Episode 90/100 - Min reward: 0.0010, Max reward: 0.7372, Mean reward: 0.2235, Last reward: 0.6738
# Episode 90/100 - Policy loss: -0.1735, Value loss: 4.2207, Entropy: 542.5481
# Time elapsed for episode 90: 10.69 seconds
# Episode 91/100 - Min reward: 0.0010, Max reward: 0.3461, Mean reward: 0.1125, Last reward: 0.0779
# Episode 91/100 - Policy loss: -0.5281, Value loss: 12.1433, Entropy: 542.4468
# Time elapsed for episode 91: 10.67 seconds
# Episode 92/100 - Min reward: 0.0010, Max reward: 0.6040, Mean reward: 0.1803, Last reward: 0.4520
# Episode 92/100 - Policy loss: -0.2201, Value loss: 3.9290, Entropy: 542.3802
# Time elapsed for episode 92: 10.68 seconds
# Episode 93/100 - Min reward: 0.0010, Max reward: 0.7873, Mean reward: 0.4751, Last reward: 0.6428
# Episode 93/100 - Policy loss: -0.2673, Value loss: 8.4306, Entropy: 542.3979
# Time elapsed for episode 93: 10.70 seconds
# Episode 94/100 - Min reward: 0.0010, Max reward: 0.7797, Mean reward: 0.3566, Last reward: 0.1914
# Episode 94/100 - Policy loss: -0.0594, Value loss: 2.8910, Entropy: 542.3262
# Time elapsed for episode 94: 10.76 seconds
# Episode 95/100 - Min reward: 0.0010, Max reward: 0.7805, Mean reward: 0.3654, Last reward: 0.7479
# Episode 95/100 - Policy loss: -0.1659, Value loss: 2.3826, Entropy: 542.2838
# Time elapsed for episode 95: 10.75 seconds
# Episode 96/100 - Min reward: 0.0355, Max reward: 0.7044, Mean reward: 0.2415, Last reward: 0.7044
# Episode 96/100 - Policy loss: -0.2574, Value loss: 4.4922, Entropy: 542.2766
# Time elapsed for episode 96: 10.69 seconds
# Episode 97/100 - Min reward: 0.0038, Max reward: 0.5996, Mean reward: 0.2390, Last reward: 0.5996
# Episode 97/100 - Policy loss: -0.3212, Value loss: 5.4369, Entropy: 542.3833
# Time elapsed for episode 97: 10.70 seconds
# Episode 98/100 - Min reward: 0.0010, Max reward: 0.6513, Mean reward: 0.0746, Last reward: 0.1597
# Episode 98/100 - Policy loss: -0.3208, Value loss: 23.6425, Entropy: 542.3672
# Time elapsed for episode 98: 10.76 seconds
# Episode 99/100 - Min reward: 0.0010, Max reward: 0.7755, Mean reward: 0.3531, Last reward: 0.6933
# Episode 99/100 - Policy loss: -0.1366, Value loss: 30.6757, Entropy: 542.3042
# Time elapsed for episode 99: 10.67 seconds
# Episode 100/100 - Min reward: 0.0010, Max reward: 0.2268, Mean reward: 0.0903, Last reward: 0.2263
# Episode 100/100 - Policy loss: -0.0653, Value loss: 2.8470, Entropy: 542.1082
# Time elapsed for episode 100: 10.76 seconds

# %%
# plot the rewards
last_rewards = [np.max(rewards) for rewards in collect_rewards]
plt.figure(figsize=(10, 5))
plt.plot(np.arange(len(collect_rewards)), last_rewards, label="Rewards")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.title("Rewards over Episodes")
plt.legend()

# %%
# plot 10 subplots in 2 x 5 grid, where each plot is one element of the collect_rewards
fig, axs = plt.subplots(2, 5, figsize=(20, 10))
for i in range(10):
    axs[i // 5, i % 5].plot(collect_rewards[10*i])
    axs[i // 5, i % 5].set_title(f"Episode {10*i + 1}")
    axs[i // 5, i % 5].set_xlabel("Time step")
    axs[i // 5, i % 5].set_ylabel("Reward")
plt.tight_layout()
plt.show()

# %%
def evaluate_agent_incidence(cfg, actor_path, threshold, num_samples=100):
    # Load agent and policy weights
    agent = PPOAgent(cfg, logger)
    agent.policy_net.load_state_dict(torch.load(actor_path, map_location="cpu"))
    agent.policy_net.eval()

    count_above = 0
    for i in range(num_samples):
        trajectory = ppo_agent.collect_trajectory(env)
        reward = np.max(trajectory['rewards'].numpy())
        if reward > threshold:
            count_above += 1
        print(f"Sample {i+1}/{num_samples}: Reward = {reward:.4f}")

    incidence_rate = count_above / num_samples
    print(f"Incidence rate (reward > {threshold}): {incidence_rate:.4f} ({count_above}/{num_samples})")
    return incidence_rate, rewards

# %%
evaluate_agent_incidence(cfg, os.path.join(save_dir, f"actor_best.pth"), 0.5, num_samples=100)
# Out:
# Sample 1/100: Reward = 0.7323
# Sample 2/100: Reward = 0.7728
# Sample 3/100: Reward = 0.6543
# Sample 4/100: Reward = 0.0957
# Sample 5/100: Reward = 0.7658
# Sample 6/100: Reward = 0.7827
# Sample 7/100: Reward = 0.5283
# Sample 8/100: Reward = 0.7970
# Sample 9/100: Reward = 0.7433
# Sample 10/100: Reward = 0.7810
# Sample 11/100: Reward = 0.6935
# Sample 12/100: Reward = 0.7259
# Sample 13/100: Reward = 0.7073
# Sample 14/100: Reward = 0.1211
# Sample 15/100: Reward = 0.2273
# Sample 16/100: Reward = 0.7202
# Sample 17/100: Reward = 0.7787
# Sample 18/100: Reward = 0.7773
# Sample 19/100: Reward = 0.6763
# Sample 20/100: Reward = 0.7822
# Sample 21/100: Reward = 0.7778
# Sample 22/100: Reward = 0.7416
# Sample 23/100: Reward = 0.7810
# Sample 24/100: Reward = 0.7141
# Sample 25/100: Reward = 0.7806
# Sample 26/100: Reward = 0.7789
# Sample 27/100: Reward = 0.7863
# Sample 28/100: Reward = 0.7162
# Sample 29/100: Reward = 0.7808
# Sample 30/100: Reward = 0.6990
# Sample 31/100: Reward = 0.7668
# Sample 32/100: Reward = 0.2470
# Sample 33/100: Reward = 0.7596
# Sample 34/100: Reward = 0.7783
# Sample 35/100: Reward = 0.7135
# Sample 36/100: Reward = 0.7831
# Sample 37/100: Reward = 0.7786
# Sample 38/100: Reward = 0.7820
# Sample 39/100: Reward = 0.5652
# Sample 40/100: Reward = 0.7570
# Sample 41/100: Reward = 0.7752
# Sample 42/100: Reward = 0.5886
# Sample 43/100: Reward = 0.7663
# Sample 44/100: Reward = 0.5472
# Sample 45/100: Reward = 0.7832
# Sample 46/100: Reward = 0.6505
# Sample 47/100: Reward = 0.7727
# Sample 48/100: Reward = 0.5086
# Sample 49/100: Reward = 0.7782
# Sample 50/100: Reward = 0.7800
# Sample 51/100: Reward = 0.7731
# Sample 52/100: Reward = 0.7830
# Sample 53/100: Reward = 0.7636
# Sample 54/100: Reward = 0.7813
# Sample 55/100: Reward = 0.7527
# Sample 56/100: Reward = 0.7727
# Sample 57/100: Reward = 0.5427
# Sample 58/100: Reward = 0.7802
# Sample 59/100: Reward = 0.7176
# Sample 60/100: Reward = 0.7435
# Sample 61/100: Reward = 0.7748
# Sample 62/100: Reward = 0.6906
# Sample 63/100: Reward = 0.7579
# Sample 64/100: Reward = 0.7795
# Sample 65/100: Reward = 0.7781
# Sample 66/100: Reward = 0.7779
# Sample 67/100: Reward = 0.7067
# Sample 68/100: Reward = 0.7790
# Sample 69/100: Reward = 0.7867
# Sample 70/100: Reward = 0.7807
# Sample 71/100: Reward = 0.7793
# Sample 72/100: Reward = 0.7062
# Sample 73/100: Reward = 0.7709
# Sample 74/100: Reward = 0.7249
# Sample 75/100: Reward = 0.5214
# Sample 76/100: Reward = 0.7798
# Sample 77/100: Reward = 0.7806
# Sample 78/100: Reward = 0.7394
# Sample 79/100: Reward = 0.5656
# Sample 80/100: Reward = 0.6749
# Sample 81/100: Reward = 0.7797
# Sample 82/100: Reward = 0.7716
# Sample 83/100: Reward = 0.7867
# Sample 84/100: Reward = 0.7719
# Sample 85/100: Reward = 0.7111
# Sample 86/100: Reward = 0.7807
# Sample 87/100: Reward = 0.7753
# Sample 88/100: Reward = 0.7770
# Sample 89/100: Reward = 0.1109
# Sample 90/100: Reward = 0.7783
# Sample 91/100: Reward = 0.7410
# Sample 92/100: Reward = 0.7771
# Sample 93/100: Reward = 0.7795
# Sample 94/100: Reward = 0.7783
# Sample 95/100: Reward = 0.7622
# Sample 96/100: Reward = 0.7945
# Sample 97/100: Reward = 0.7744
# Sample 98/100: Reward = 0.7620
# Sample 99/100: Reward = 0.7548
# Sample 100/100: Reward = 0.7807
# Incidence rate (reward > 0.5): 0.9500 (95/100)
# (0.95,
#  tensor([0.0010, 0.0010, 0.0768, 0.0781, 0.0772, 0.0776, 0.0777, 0.0800, 0.1211,
#          0.0771, 0.0770, 0.0771, 0.0772, 0.0794, 0.0790, 0.1110, 0.0771, 0.0774,
#          0.0770, 0.0770, 0.0770, 0.0770, 0.0770, 0.0770, 0.0770, 0.0770, 0.0770,
#          0.0770, 0.0770, 0.0881, 0.0896, 0.0886, 0.0998, 0.0861, 0.0771, 0.0770,
#          0.0779, 0.0770, 0.0850, 0.1009, 0.0770, 0.0792, 0.2268, 0.1783, 0.1226,
#          0.1258, 0.1411, 0.1248, 0.0946, 0.2263]))
